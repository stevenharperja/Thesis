# %%
import torch

print(torch.cuda.is_available())   # should be True
# print(torch.cuda.device_count())   # >= 1
# print(torch.cuda.get_device_name(0))

# %%
import transformers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transformers import torch_device
#       2 print(torch_device)
#
# ImportError: cannot import name 'torch_device' from 'transformers' (c:\Users\shwes\Projects\Thesis\.venv\Lib\site-packages\transformers\__init__.py)

# %%
import torch
import numpy as np 
import low_rank

# %% [markdown]
# Load data

# %% [markdown]
# Load models

# %% [markdown]
# Convert to low rank approximations

# %% [markdown]
# Compare results of each model
